# %% [markdown]
# # Stock price and return time series

# %% [markdown]
# ### Get data

# %%
import pandas as pd
import statsmodels.api as sm
from scipy import stats
import pydy
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('T1_ts_data_-1337276833.xlsx')

# %%
data.set_index('Date',inplace = True)

# %%
data
# Out:
#                      FTSE100      BP   SHELL
# Date
# 2011-01-07 16:30:00  5984.33  492.50  2109.0
# 2011-01-14 16:30:00  6002.07  499.50  2118.5
# 2011-01-21 16:30:00  5896.25  497.30  2142.5
# 2011-01-28 16:30:00  5881.37  486.80  2202.5
# 2011-02-04 16:30:00  5997.38  476.25  2155.0
# ...                      ...     ...     ...
# 2022-12-02 16:30:00  7556.23  480.90  2365.5
# 2022-12-09 16:30:00  7476.63  461.95  2286.0
# 2022-12-16 16:30:00  7332.12  455.40  2243.0
# 2022-12-23 12:30:00  7473.01  478.90  2366.5
# 2022-12-30 12:30:00  7451.74  474.90  2326.0
#
# [626 rows x 3 columns]

# %% [markdown]
# ### Simple plots for FTSE100, BP, and Shell

# %%
plt.plot(data['FTSE100'])

# %%
plt.plot(data['BP'])

# %%
plt.plot(data['SHELL'])

# %%
plt.figure(figsize=(12,6))

# %%
# Loop through each stock column (assuming 'BP', 'SHELL', and another)
for col in ['FTSE100','BP', 'SHELL']:
  plt.plot(data.index, data[col], label=col)  # Plot with label for legend

# Add legend to distinguish lines
plt.legend()

plt.title('Stock Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))

bp, = plt.plot(data['BP'],label = 'BP',color = 'b')
plt.legend()
ax2 = plt.twinx()
shell, = ax2.plot(data['SHELL'],label = 'SHELL',color = 'g')
plt.legend(handles=[bp,shell])



plt.title('BP and Shell Stock Prices')
plt.xlabel('Date')
plt.ylabel('Prices')
# Out:
# Text(0, 0.5, 'Prices')

# %% [markdown]
# ### Plot the returns for each asset

# %%
returns = data.pct_change()

# %%
returns
# Out:
#                       FTSE100        BP     SHELL
# Date
# 2011-01-07 16:30:00       NaN       NaN       NaN
# 2011-01-14 16:30:00  0.002964  0.014213  0.004505
# 2011-01-21 16:30:00 -0.017631 -0.004404  0.011329
# 2011-01-28 16:30:00 -0.002524 -0.021114  0.028005
# 2011-02-04 16:30:00  0.019725 -0.021672 -0.021566
# ...                       ...       ...       ...
# 2022-12-02 16:30:00  0.009291 -0.015255 -0.000634
# 2022-12-09 16:30:00 -0.010534 -0.039405 -0.033608
# 2022-12-16 16:30:00 -0.019328 -0.014179 -0.018810
# 2022-12-23 12:30:00  0.019215  0.051603  0.055060
# 2022-12-30 12:30:00 -0.002846 -0.008352 -0.017114
#
# [626 rows x 3 columns]

# %%
returns = returns[1:] #get rid of initial NAN

# %%
plt.plot(returns['FTSE100'])

# %%
plt.plot(returns['BP'])

# %%
plt.plot(returns['SHELL'])

# %%
plt.figure(figsize=(12,6))

# %%
# Loop through each stock column (assuming 'BP', 'SHELL', and another)
for col in ['FTSE100','BP', 'SHELL']:
  plt.plot(returns.index, returns[col], label=col)  # Plot with label for legend

# Add legend to distinguish lines
plt.legend()

plt.title('Stock Prices')
plt.xlabel('Date')
plt.ylabel('Returns')
plt.grid(True)
plt.tight_layout()
plt.show()
